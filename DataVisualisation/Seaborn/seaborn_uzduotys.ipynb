# %% [markdown]
# # Seaborn užduotys

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
mpg = sns.load_dataset('mpg')

# %%
mpg.tail(10)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 388  26.0          4         156.0        92.0    2585          14.5
# 389  22.0          6         232.0       112.0    2835          14.7
# 390  32.0          4         144.0        96.0    2665          13.9
# 391  36.0          4         135.0        84.0    2370          13.0
# 392  27.0          4         151.0        90.0    2950          17.3
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                        name
# 388          82     usa  chrysler lebaron medallion
# 389          82     usa              ford granada l
# ...

# %%
mpg.shape
# Out:
# (398, 9)

# %% [markdown]
# **Reikšmės, kurios galbūt ne visai aiškios:**
# * mpg - miles per gallon
# * displacement - variklio tūris kubiniais coliais. Jei norite pasisunkinti, galite perkaičiuoti stulpelius europietiškais standartais :)

# %% [markdown]
# # 1 Atspausdinkite histogramą, kurioje matytųsi, kiek automobilių turi kokius variklio tūrius. *Šioje ir kitose užduotyse žaiskite su stiliais ir spalvomis, taip, kaip jums patinka.*

# %%
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='Count'>

# %% [markdown]
# # 2 Atspausdinkite histogramą, kurioje matytųsi, kiek automobilių turi kokią akseleraciją. Nuspalvinkite informaciją pagal šalis

# %%
# Out:
# <AxesSubplot:xlabel='acceleration', ylabel='Count'>

# %% [markdown]
# # 3 Naudodami countplot atspausdinkite grafiką, kuriame matytųsi, kokie yra cilindrų skaičiaus variantai.

# %%
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='count'>

# %% [markdown]
# # 4 Naudodami countplot atspausdinkite grafiką, kuriame matytųsi, kiek yra pagaminimo metų variantų. Suskirstykite pagal šalis

# %%
# Out:
# <AxesSubplot:xlabel='model_year', ylabel='count'>

# %% [markdown]
# # 5 Naudodami countplot atspausdinkite grafiką, kurioje matytųsi, kiek automobilių lentelėje kokia šalis pagamino. Panaudokite horizontalų grafiką, išskirstykite pagal cilindrus

# %%
# Out:
# <AxesSubplot:xlabel='count', ylabel='origin'>

# %% [markdown]
# # 6 Atspausdinkite stulpelinę diagramą, kurioje matytųsi, koks kurioje šalyje pagamintų automobilių variklio tūrio vidurkis.

# %%
# Out:
# <AxesSubplot:xlabel='origin', ylabel='displacement'>

# %% [markdown]
# # 7 Atspausdinkite sklaidos diagramą, kurios x ašis būtų 'displacement', y - 'acceleration', taip pat kiekvienas taškas atspindėtų šalį gamintoją ir cilindrų skaičių

# %%
# Out:
# <AxesSubplot:xlabel='displacement', ylabel='acceleration'>

# %% [markdown]
# # 8 Atspausdinkite visas įmanomas sklaidos diagramas lentelėje, kur pagal taško spalvą matytumėm šalį gamintoją. Kokias tendencijas galima aiškiai išskirti?

# %% [markdown]
# # 9 Atspausdinkite stačiakampę diagramą, 'origin' x 'mpg'. Pabandykite interpretuoti rezultatą.

# %%
# Out:
# <AxesSubplot:xlabel='origin', ylabel='mpg'>

# %% [markdown]
# # 10 Sukurkite koreliacijų matricą. Jos pagrindu atspausdinkite mozaikinę diagramą.

# %%
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.775396     -0.804203   -0.778427 -0.831741
# cylinders    -0.775396   1.000000      0.950721    0.842983  0.896017
# displacement -0.804203   0.950721      1.000000    0.897257  0.932824
# horsepower   -0.778427   0.842983      0.897257    1.000000  0.864538
# weight       -0.831741   0.896017      0.932824    0.864538  1.000000
# acceleration  0.420289  -0.505419     -0.543684   -0.689196 -0.417457
# model_year    0.579267  -0.348746     -0.370164   -0.416361 -0.306564
#
#               acceleration  model_year
# mpg               0.420289    0.579267
# cylinders        -0.505419   -0.348746
# displacement     -0.543684   -0.370164
# horsepower       -0.689196   -0.416361
# weight           -0.417457   -0.306564
# acceleration      1.000000    0.288137
# model_year        0.288137    1.000000

# %%
# Out:
# <AxesSubplot:>

# %% [markdown]
# # 11 Atspausdinkite sklaidos diagramų rinkinį, kuriame kiekviena lentelė pagal šalį rodytų 'acceleration' ir 'cylinders' sąntykį.
