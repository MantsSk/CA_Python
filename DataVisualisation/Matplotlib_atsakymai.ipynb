# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1 Atspausdinkite taškus grafike (x=5, y=2) ir (x=11, y=5)

# %%
x = [5,11]
y = [2,5]

plt.plot(x,y, "o")

# %% [markdown]
# ## 2 Atspausdinkite linija kuri taškuota ir raudona (x=22, y=44) ir (x=14, y=28)

# %%
x = [22,14]
y = [44,28]

plt.plot(x,y, color="red", linestyle='dotted')

# %% [markdown]
# ## Panaudojame csv

# %%
import pandas as pd

data = pd.read_csv('mpg.csv')

# %%
data.shape
data.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %% [markdown]
# **Reikšmės, kurios galbūt ne visai aiškios:**
# * mpg - miles per gallon
# * displacement - variklio tūris kubiniais coliais. Jei norite pasisunkinti, galite perkaičiuoti stulpelius europietiškais standartais :)

# %% [markdown]
# ## 3 Atspausdinkite kelias linijas kurios parodo horsepower, weight ir acceleration. Atspausdinkite pirmus 10. Formatavimą galite daryti pagal save

# %%
import pandas as pd

data = pd.read_csv('mpg.csv').head(10)
horsepower = data['horsepower']
weight = data['weight'] 
acceleration = data['acceleration']

plt.plot(horsepower, label="Horsepower", color="r", linestyle="--", marker=".")
plt.plot(weight, label="Weight", color="b")
plt.plot(acceleration, label="Tip", color="g")

# %% [markdown]
# ## 4 Atspausdinkite kelis stulpelinius grafikus kurie parodo horsepower, weight ir displacement. Atspausdinkite pirmus 10. Formatavimą galite daryti pagal save

# %%
import pandas as pd

data = pd.read_csv('mpg.csv').head(10)

horsepower = data['horsepower']
weight = data['weight'] 
displacement = data['displacement']

width=0.25

plt.bar(horsepower.index-width, horsepower, label="Horsepower", color="r", width=width)
plt.bar(weight.index, weight, label="Weight", color="b", width=width)
plt.bar(displacement.index+width, displacement, label="Displacement", color="g", width=width)

plt.legend()

# %% [markdown]
# ## 5 Atspausdinkite skritulinę diagrama kuri procentais parodo kiek mašinų pagaminta USA ir kiek Japonijoje. Patarimas - galite naudoti pandas filtrą ir count

# %%
data = pd.read_csv('mpg.csv')

usa_filter = (data['origin'] == 'usa')
japan_filter = (data['origin'] == 'japan')

usa = data.loc[usa_filter, 'origin']
japan = data.loc[japan_filter, 'origin']

values = [usa.count(), japan.count()]
labels = ["USA", "JAPAN"]
explode = [0,0.1]

plt.pie(values, startangle=90, labels=labels, explode=explode, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f89046d77f0>,
#   <matplotlib.patches.Wedge at 0x7f89046d7f10>],
#  [Text(-0.7551496088235982, -0.7998431523077302, 'USA'),
#   Text(0.8237996141094087, 0.8725561275890448, 'JAPAN')],
#  [Text(-0.4118997866310535, -0.43627808307694366, '75.9%'),
#   Text(0.480549774897155, 0.5089910744269427, '24.1%')])

# %% [markdown]
# ## 6 Atspausdinkite skritulinę diagrama kuri procentais parodo model_year pasiskirstymą

# %%
data = pd.read_csv('mpg.csv')

# values = data.groupby(['model_year']).sum()

values = data['model_year'].value_counts().tolist()
labels = data['model_year'].value_counts().index.tolist()

print(values)
print(labels)

plt.pie(values, labels=labels,  autopct='%1.1f%%')
# Out:
# [40, 36, 34, 31, 30, 29, 29, 29, 29, 28, 28, 28, 27]
# [73, 78, 76, 82, 75, 70, 79, 80, 81, 71, 72, 77, 74]
# ([<matplotlib.patches.Wedge at 0x7f896440af40>,
#   <matplotlib.patches.Wedge at 0x7f89047446a0>,
#   <matplotlib.patches.Wedge at 0x7f8904744d90>,
#   <matplotlib.patches.Wedge at 0x7f890474d4f0>,
#   <matplotlib.patches.Wedge at 0x7f890474dc10>,
#   <matplotlib.patches.Wedge at 0x7f8904758370>,
#   <matplotlib.patches.Wedge at 0x7f8904758a90>,
#   <matplotlib.patches.Wedge at 0x7f89047631f0>,
#   <matplotlib.patches.Wedge at 0x7f8904763910>,
#   <matplotlib.patches.Wedge at 0x7f890476d070>,
#   <matplotlib.patches.Wedge at 0x7f896440af10>,
#   <matplotlib.patches.Wedge at 0x7f890476de80>,
#   <matplotlib.patches.Wedge at 0x7f89047775e0>],
#  [Text(1.0456242374828657, 0.34156983764433263, '73'),
#   Text(0.6702114664107667, 0.8722480096231404, '78'),
#   Text(0.11267832536458751, 1.094213687993818, '76'),
#   Text(-0.438933623826976, 1.008631386520427, '82'),
#   Text(-0.8561341108136539, 0.690676758188166, '75'),
#   Text(-1.0751126149483357, 0.2326647054861386, '70'),
#   Text(-1.0672318666319907, -0.26648854167711844, '79'),
#   Text(-0.8395401001736524, -0.7107548242540559, '80'),
#   Text(-0.4389335530008104, -1.0086314173423734, '81'),
#   Text(0.043402766857428776, -1.0991433936612274, '71'),
#   Text(0.5094204846151029, -0.9749311615978402, '72'),
#   Text(0.8775110851178383, -0.663305582288672, '77'),
#   Text(1.0751126203942458, -0.23266468032131205, '74')],
#  [Text(0.5703404931724722, 0.18631082053327233, '10.1%'),
#   Text(0.365569890769509, 0.475771641612622, '9.0%'),
#   Text(0.06146090474432045, 0.5968438298148098, '8.5%'),
#   Text(-0.2394183402692596, 0.5501625744656874, '7.8%'),
#   Text(-0.466982242261993, 0.3767327771935451, '7.5%'),
#   Text(-0.5864250626990921, 0.1269080211742574, '7.3%'),
#   Text(-0.5821264727083585, -0.14535738636933732, '7.3%'),
#   Text(-0.4579309637310831, -0.38768444959312137, '7.3%'),
#   Text(-0.2394183016368056, -0.5501625912776581, '7.3%'),
#   Text(0.02367423646768842, -0.5995327601788513, '7.0%'),
#   Text(0.2778657188809652, -0.5317806335988219, '7.0%'),
#   Text(0.4786424100642754, -0.36180304488473014, '7.0%'),
#   Text(0.5864250656695886, -0.12690800744798836, '6.8%')])

# %% [markdown]
# ## 7 Atspausdinkite skritulinę diagrama kuri skaičiais parodo model_year pasiskirstymą

# %%
data = pd.read_csv('mpg.csv')

# values = data.groupby(['model_year']).sum()

values = data['origin'].value_counts().tolist()
labels = data['origin'].value_counts().index.tolist()

print(values)
print(labels)

total = sum(values)
plt.pie(values, labels=labels, autopct=lambda p: '{:.0f}'.format(p * total / 100))
# Out:
# [249, 79, 70]
# ['usa', 'japan', 'europe']
# ([<matplotlib.patches.Wedge at 0x7f8904894ca0>,
#   <matplotlib.patches.Wedge at 0x7f89646fc400>,
#   <matplotlib.patches.Wedge at 0x7f89646fcb20>],
#  [Text(-0.42295633254055504, 1.015434853037773, 'usa'),
#   Text(-0.1729356138822676, -1.0863209808574827, 'japan'),
#   Text(0.93631267527795, -0.5773374871891209, 'europe')],
#  [Text(-0.23070345411303, 0.5538735562024215, '249'),
#   Text(-0.09432851666305504, -0.5925387168313542, '79'),
#   Text(0.5107160046970636, -0.3149113566486114, '70')])

# %%
## ū Atspausdinkite histogramas kuri parodo aksleracijos pasiskirstymą

# %%
data = pd.read_csv('mpg.csv')

acceleration = data['acceleration'] 

plt.grid(True)
plt.hist(acceleration, label="cylinders", edgecolor="black", facecolor='g')
plt.legend()

# %%
## 9 Atspausdinkite sklaidos diagramą kurioje parodomas saryšis tarp displacement ir aksceleracijos

# %%
data = pd.read_csv('mpg.csv')

origin = data['origin'] 
acceleration = data['acceleration'] 

plt.scatter(x=displacement, y=acceleration, s=displacement, c=acceleration, cmap="Greens" )
plt.title("Scatter plot")
plt.xlabel("Displacement")
plt.ylabel("Acceleration")
# Out:
# Text(0, 0.5, 'Acceleration')

# %% [markdown]
# ## 10
# ###### Parsisiųsti countries.csv failą iš https://www.csdojo.io/data
# ######  Susikurti iš jo duomenų paketą (Pandas DataFrame)
# ######  Atspausdinti tik metų stulpelį
# ###### Atspausdinti norimos šalies didžiausius/mažiausius/vidutinius gyventojų kiekius
# ###### Atspausdinti bendrą lentelės ataskaitą
# ###### Grafike atvaizduoti kelių skirtingų šalių populiacijos pokytį per metus
# ###### Padaryti, kad grafikas turėtų pavadinimą, būtų įvardintos x/y ašys bei kreivės

# %%
from pandas import pandas as pd

df = pd.read_csv('countries.csv')

df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
from matplotlib import pyplot as plt

australia = df[df.country == 'Australia']
germany = df[df.country == 'Germany']

plt.plot(australia.year, australia.population / 10**6)
plt.plot(germany.year, germany.population / 10**6)
plt.legend(['Australija', 'Vokietija'])
plt.xlabel('Metai')
plt.ylabel('Populiacija (mln.)')
plt.show()
